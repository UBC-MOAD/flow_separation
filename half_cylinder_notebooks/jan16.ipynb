# %% [markdown]
# This code compares the results of the free-slip and no-slip-over-cylinder-runs.

# %%
import numpy as np
import matplotlib.pyplot as plt
from MITgcmutils import rdmds

import matplotlib.pylab as pylab

# %matplotlib inline

# %%
x = np.squeeze(rdmds('../No_Slip_Cylinder/run3/XC'))
z = np.squeeze(rdmds('../No_Slip_Cylinder/run3/RC'))
# Out:
# ../No_Slip_Cylinder/run3/XC.001.001.meta
# ../No_Slip_Cylinder/run3/RC.meta

# %%
UFS = np.squeeze(rdmds('../Free_Slip_Cylinder/run1/U',2000))
UNS = np.squeeze(rdmds('../No_Slip_Cylinder/run1/U',2000))

pylab.rcParams['figure.figsize'] = (20,8)

plt.figure()
plt.subplot(1,3,1)
plt.pcolor(x,z,UFS,cmap='Spectral_r')
plt.colorbar()
plt.xlim((0.15,0.25))
plt.ylim((-0.2,-0.15))
plt.title('Free slip U output')

plt.subplot(1,3,2)
plt.pcolor(x,z,UNS,cmap='Spectral_r')
plt.colorbar()
plt.xlim((0.15,0.25))
plt.ylim((-0.2,-0.15))
plt.title('No slip U output')

plt.subplot(1,3,3)
plt.pcolor(x,z,UNS-UFS,cmap='Spectral_r')
plt.colorbar()
plt.xlim((0.15,0.25))
plt.ylim((-0.2,-0.15))
plt.title('No slip U minus free slip U')

plt.suptitle('Early time output comparison')
plt.show()
# Out:
# ../Free_Slip_Cylinder/run1/U.0000002000.001.001.meta
# ../No_Slip_Cylinder/run1/U.0000002000.001.001.meta

# %%
UFS = np.squeeze(rdmds('../Free_Slip_Cylinder/run1/U',16400))
UNS = np.squeeze(rdmds('../No_Slip_Cylinder/run1/U',16400))

pylab.rcParams['figure.figsize'] = (20,8)

plt.figure()
plt.subplot(1,3,1)
plt.pcolor(x,z,UFS,cmap='Spectral_r')
plt.colorbar()
plt.xlim((0.15,0.25))
plt.ylim((-0.2,-0.15))
plt.title('Free slip U output')

plt.subplot(1,3,2)
plt.pcolor(x,z,UNS,cmap='Spectral_r')
plt.colorbar()
plt.xlim((0.15,0.25))
plt.ylim((-0.2,-0.15))
plt.title('No slip U output')

plt.subplot(1,3,3)
plt.pcolor(x,z,UNS-UFS,cmap='Spectral_r')
plt.colorbar()
plt.xlim((0.15,0.25))
plt.ylim((-0.2,-0.15))
plt.title('No slip U minus free slip U')

plt.suptitle('Later time output comparison')
plt.show()
# Out:
# ../Free_Slip_Cylinder/run1/U.0000016400.001.001.meta
# ../No_Slip_Cylinder/run1/U.0000016400.001.001.meta

# %%
plt.figure()

UNS = np.squeeze(rdmds('../No_Slip_Cylinder/run3/U',52000))

plt.pcolor(x,z,UNS,cmap='Spectral_r')
#plt.xlim((0.15,0.2))
#plt.ylim((-0.4,-0.3))
plt.colorbar()
plt.title('Focus on numerical instability')

plt.show()
# Out:
# ../No_Slip_Cylinder/run3/U.0000052000.001.001.meta
