# %% [markdown]
# This notebook compares flow-over cylinder runs at different resolutions. Compares separation point as a function of time.

# %%
import cylinder_utils as cu
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
from MITgcmutils import rdmds

import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = (16,12)

from matplotlib import rc
#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

# %matplotlib inline

# %% [markdown]
# The following cell loads in the grid coordinates and sets the variable run parameters.

# %%
Ncomps = 2
Nx = [1024,2048]
Nz = [256,1024]

dirs = ['../../CylinderNx1024Nz256_001/RUN1','../../CylinderNx2048Nz1024_001']

X=[0]*Ncomps
Z=[0]*Ncomps
dt=[0]*Ncomps
R0=[0]*Ncomps
Lx=[0]*Ncomps
Lz=[0]*Ncomps

dt[0] = 2.5e-4
dt[1] = 1.25e-4
#dt[2] = 2.5e-4

Lx[0] = 0.4
Lx[1] = 0.4
#Lx[2] = 0.4

Lz[0] = 0.1
Lz[1] = 0.1
#Lz[2] = 0.1

R0[0] = 0.025
R0[1] = 0.025
#R0[2] = 0.025

del_out = [0]*Ncomps
max_out = [0]*Ncomps

tmax = 6.0

for ii in range(0,Ncomps):
    del_out[ii] = int(1.0/dt[ii])
    max_out[ii] = int(tmax/dt[ii])
    X[ii] = np.squeeze(rdmds(dirs[ii]+'/XC')-Lx[ii]/2)
    Z[ii] = np.squeeze(rdmds(dirs[ii]+'/RC')+Lz[ii])
# Out:
# ../../CylinderNx1024Nz256_001/RUN1/XC.001.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/RC.meta
# ../../CylinderNx2048Nz1024_001/XC.015.001.meta
# ../../CylinderNx2048Nz1024_001/RC.meta

# %% [markdown]
# This cell confirms that the calc_dvtheta_dr function is working correctly; debug cell

# %%
jj = 0
T=np.squeeze(rdmds(dirs[jj]+'/T',0))
bd_pts = cu.find_bdy(X[jj],Z[jj],R0[jj],T)
tmplst = []
U=np.squeeze(rdmds(dirs[jj]+'/U',0))
W=np.squeeze(rdmds(dirs[jj]+'/W',0))
[theta_bd,dvtheta_dr_bd] = cu.calc_dvtheta_dr(X[jj],Z[jj],U,W,R0[jj],Nx[jj],Nz[jj],bd_pts)
plt.plot(theta_bd,dvtheta_dr_bd)
plt.plot(theta_bd,np.zeros(len(theta_bd)),'--k')
plt.ylim((-200,200))
plt.show()
# Out:
# ../../CylinderNx1024Nz256_001/RUN1/T.0000000000.001.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/U.0000000000.004.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/W.0000000000.004.001.meta

# %% [markdown]
# This cell does the bulk of the work. Calculates the separation point at each output for each comparison directory

# %%
sep_pt = [0]*Ncomps
for jj in range(0,Ncomps):
    T=np.squeeze(rdmds(dirs[jj]+'/T',0))
    bd_pts = cu.find_bdy(X[jj],Z[jj],R0[jj],T)
    tmplst = []
    for ii in range(0,max_out[jj]+1,del_out[jj]):
        U=np.squeeze(rdmds(dirs[jj]+'/U',ii))
        W=np.squeeze(rdmds(dirs[jj]+'/W',ii))
        [theta_bd,dvtheta_dr_bd] = cu.calc_dvtheta_dr(X[jj],Z[jj],U,W,R0[jj],Nx[jj],Nz[jj],bd_pts)
        tmplst.append(cu.find_zero(theta_bd,dvtheta_dr_bd))
    sep_pt[jj] = tmplst
# Out:
# ../../CylinderNx1024Nz256_001/RUN1/T.0000000000.001.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/U.0000000000.004.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/W.0000000000.004.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/U.0000004000.004.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/W.0000004000.001.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/U.0000008000.001.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/W.0000008000.004.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/U.0000012000.001.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/W.0000012000.004.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/U.0000016000.002.001.meta
# Found zero!
# Found zero!
# Found zero!
# ../../CylinderNx1024Nz256_001/RUN1/W.0000016000.002.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/U.0000020000.003.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/W.0000020000.001.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/U.0000024000.004.001.meta
# Found zero!
# Found zero!
# ../../CylinderNx1024Nz256_001/RUN1/W.0000024000.002.001.meta
# ../../CylinderNx2048Nz1024_001/T.0000000000.012.001.meta
# ../../CylinderNx2048Nz1024_001/U.0000000000.012.001.meta
# ../../CylinderNx2048Nz1024_001/W.0000000000.011.001.meta
# ../../CylinderNx2048Nz1024_001/U.0000008000.008.001.meta
# ../../CylinderNx2048Nz1024_001/W.0000008000.016.001.meta
# ../../CylinderNx2048Nz1024_001/U.0000016000.010.001.meta
# ../../CylinderNx2048Nz1024_001/W.0000016000.002.001.meta
# ../../CylinderNx2048Nz1024_001/U.0000024000.007.001.meta
# Found zero!
# ../../CylinderNx2048Nz1024_001/W.0000024000.015.001.meta
# ../../CylinderNx2048Nz1024_001/U.0000032000.012.001.meta
# Found zero!
# ../../CylinderNx2048Nz1024_001/W.0000032000.008.001.meta
# ../../CylinderNx2048Nz1024_001/U.0000040000.011.001.meta
# Found zero!
# ../../CylinderNx2048Nz1024_001/W.0000040000.007.001.meta
# ../../CylinderNx2048Nz1024_001/U.0000048000.015.001.meta
# Found zero!
# ../../CylinderNx2048Nz1024_001/W.0000048000.001.001.meta

# %% [markdown]
# This cell simply plots the data calculated in the previous cell

# %%
form = ['-or','--ob','-og']
for ii in range(Ncomps):
    plt.plot(sep_pt[ii],form[ii])
plt.legend(('1024x256','2048x1024'))
plt.xlabel('time in seconds')
plt.ylabel('separation angle')
plt.show()

# %% [markdown]
# This cell highlights the boundary points used in each simulation.

# %%
pylab.rcParams['figure.figsize'] = (32,12)

for sel in range(0,Ncomps):

    T = np.squeeze(rdmds(dirs[sel]+'/T',0))
    bd_pts = cu.find_bdy(X[sel],Z[sel],R0[sel],T)

    U = np.squeeze(rdmds(dirs[sel]+'/U',2*del_out[sel]))

    plt.subplot(1,Ncomps,sel+1)
    plt.pcolor(X[sel],Z[sel],U)
    plt.colorbar()
    for jj in bd_pts:
        plt.plot(X[sel][jj[1]],Z[sel][jj[0]],'ok')

    plt.xlim((0,0.0125))
    plt.ylim((0.02,0.03))
    
plt.show()
# Out:
# ../../CylinderNx1024Nz256_001/RUN1/T.0000000000.001.001.meta
# ../../CylinderNx1024Nz256_001/RUN1/U.0000008000.001.001.meta
# ../../CylinderNx2048Nz1024_001/T.0000000000.012.001.meta
# ../../CylinderNx2048Nz1024_001/U.0000016000.010.001.meta

# %% [markdown]
# This cell calculates the flow potential, phi.

# %%
sel = 1

U=np.squeeze(rdmds(dirs[sel]+'/U',1*del_out[sel]))
W=np.squeeze(rdmds(dirs[sel]+'/W',1*del_out[sel]))
T = np.squeeze(rdmds(dirs[sel]+'/T',0))
bd_pts = cu.find_bdy(X[sel],Z[sel],R0[sel],T)

phi = cu.calc_phi(X[sel],Z[sel],U,W,bd_pts)

plt.pcolor(X[sel],Z[sel],phi)
plt.colorbar()
plt.show()
# Out:
# ../../CylinderNx256Nz64_nograv/U.0000000250.001.001.meta
# ../../CylinderNx256Nz64_nograv/W.0000000250.001.001.meta
# ../../CylinderNx256Nz64_nograv/T.0000000000.001.001.meta

# %%
def calc_dx2(U,X):
    uext_r = U[:,1:]
    uext_r = np.append(uext_r, 0.01+np.zeros((256,1)), 1)
    uext_l = U[:,0:-1]
    uext_l = np.append(0.01+np.zeros((256,1)),uext_l, 1)
    
    print uext_r.shape
    print uext_l.shape
    print U.shape
    
    u_xx = (uext_r-2*U+uext_l)/((X[1]-X[0])**2)
    return u_xx

# %%
def calc_dz2(U,Z):
    uext_u = U[1:,:]
    uext_u = np.append(uext_u, np.zeros((1,1024)), 0)
    uext_d = U[0:-1,:]
    uext_d = np.append(np.zeros((1,1024)),uext_d, 0)
    
    print uext_u.shape
    print uext_d.shape
    print U.shape
    
    u_zz = (uext_u-2*U+uext_d)/((Z[1]-Z[0])**2)
    return u_zz

# %%
sel = 2

dpt = np.squeeze(rdmds(dirs[sel]+'/Depth'))
U=np.squeeze(rdmds(dirs[sel]+'/U',1*del_out[sel]))
W=np.squeeze(rdmds(dirs[sel]+'/W',1*del_out[sel]))

phi = cu.calc_phi(X[sel],Z[sel],U,W,bd_pts)
phi_xx = calc_dx2(phi,X[sel])
phi_zz = calc_dz2(phi,Z[sel])

print np.mean(phi_xx+phi_zz)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-0537431c92d7> in <module>()
#       1 sel = 2
#       2
# ----> 3 dpt = np.squeeze(rdmds(dirs[sel]+'/Depth'))
#       4 U=np.squeeze(rdmds(dirs[sel]+'/U',1*del_out[sel]))
#       5 W=np.squeeze(rdmds(dirs[sel]+'/W',1*del_out[sel]))
#
# IndexError: list index out of range

# %%
pylab.rcParams['figure.figsize'] = (32,12)

plt.pcolor(X[2],Z[2],phi_xx+phi_zz,cmap='Spectral_r')
plt.plot(X[2],0.1-dpt,'-og')
plt.colorbar()
plt.clim((-100,100))
plt.show()

# %%
U = []
outnum = 35

for ii in range(Ncomps):
    dpt = np.squeeze(rdmds(dirs[ii]+'/Depth'))
    U.append(np.squeeze(rdmds(dirs[ii]+'/U',outnum*del_out[ii])))
    plt.subplot(1,3,ii+1)
    plt.pcolor(X[ii],Z[ii],U[ii],shading='faceted')
    xsep = R0[ii]*np.cos(np.pi-sep_pt[ii][outnum]*np.pi/180.0)
    zsep = R0[ii]*np.sin(np.pi-sep_pt[ii][outnum]*np.pi/180.0)
    plt.plot(xsep,zsep,'ok')
    plt.plot(X[ii],0.1-dpt,drawstyle='steps')
    plt.xlim((0.0,0.025))
    plt.ylim((0.0,0.025))
    
plt.show()
# Out:
# ../../CylinderNx256Nz64_001/Depth.001.001.meta
# ../../CylinderNx256Nz64_001/U.0000008750.001.001.meta
# /home/rirwin/anaconda/lib/python2.7/site-packages/matplotlib/cbook.py:122: MatplotlibDeprecationWarning: The shading option was deprecated in version 1.2. Use edgecolors instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# ../../CylinderNx1024Nz128_002/Depth.004.001.meta
# ../../CylinderNx1024Nz128_002/U.0000035000.003.001.meta
# ../../CylinderNx1024Nz256_001/Depth.004.001.meta
# ../../CylinderNx1024Nz256_001/U.0000140000.004.001.meta

# %%
U[-1,:].shape
# Out:
# (1024,)
